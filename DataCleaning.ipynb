# %%
import pandas as pd

# %%
data = pd.read_csv('n_movies.csv')

# %%
data.head()
# Out:
#                     title         year certificate duration  \
# 0               Cobra Kai     (2018– )       TV-14   30 min
# 1               The Crown     (2016– )       TV-MA   58 min
# 2        Better Call Saul  (2015–2022)       TV-MA   46 min
# 3           Devil in Ohio        -2022       TV-MA  356 min
# 4  Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
#
#                           genre  rating  \
# 0         Action, Comedy, Drama     8.5
# 1     Biography, Drama, History     8.7
# 2                  Crime, Drama     8.9
# 3        Drama, Horror, Mystery     5.9
# 4  Animation, Action, Adventure     8.6
#
#                                          description  \
# 0  Decades after their 1984 All Valley Karate Tou...
# 1  Follows the political rivalries and romance of...
# 2  The trials and tribulations of criminal lawyer...
# 3  When a psychiatrist shelters a mysterious cult...
# 4  A Street Kid trying to survive in a technology...
#
# ...

# %%
data['year'] = data['year'].str[1:5]

# %%
data['year']
# Out:
# 0       2018
# 1       2016
# 2       2015
# 3       2022
# 4       2022
#         ...
# 9952    2022
# 9953    2010
# 9954    2016
# 9955    2005
# 9956    2022
# Name: year, Length: 9957, dtype: object

# %%
data.dtypes
# Out:
# title           object
# year            object
# certificate     object
# duration        object
# genre           object
# rating         float64
# description     object
# stars           object
# votes           object
# dtype: object

# %%
data['duration'] = data['duration'].str.replace(r'\D', '').astype('float')
data['duration']
# Out:
# 0        30.0
# 1        58.0
# 2        46.0
# 3       356.0
# 4        24.0
#         ...
# 9952     45.0
# 9953     44.0
# 9954     58.0
# 9955     44.0
# 9956    356.0
# Name: duration, Length: 9957, dtype: float64

# %%
data['duration']
# Out:
# 0        30.0
# 1        58.0
# 2        46.0
# 3       356.0
# 4        24.0
#         ...
# 9952     45.0
# 9953     44.0
# 9954     58.0
# 9955     44.0
# 9956    356.0
# Name: duration, Length: 9957, dtype: float64

# %%
df1 = data

# %%
mean = data['duration'].mean()
mean
# Out:
# 73.77161974498169

# %%
data['duration'] = data['duration'].fillna(mean)

# %%
data.isnull().sum()
# Out:
# title             0
# year            527
# certificate    3453
# duration          0
# genre            73
# rating         1173
# description       0
# stars             0
# votes          1173
# dtype: int64

# %%
data.dtypes
# Out:
# title           object
# year            object
# certificate     object
# duration       float64
# genre           object
# rating         float64
# description     object
# stars           object
# votes           object
# dtype: object

# %%
data[['main_genre','middle','right']] = data['genre'].str.split('[,]', expand=True)

# %%
data
# Out:
#                        title  year certificate  duration  \
# 0                  Cobra Kai  2018       TV-14      30.0
# 1                  The Crown  2016       TV-MA      58.0
# 2           Better Call Saul  2015       TV-MA      46.0
# 3              Devil in Ohio  2022       TV-MA     356.0
# 4     Cyberpunk: Edgerunners  2022       TV-MA      24.0
# ...                      ...   ...         ...       ...
# 9952          The Imperfects  2022       TV-MA      45.0
# 9953        The Walking Dead  2010       TV-MA      44.0
# 9954               The Crown  2016       TV-MA      58.0
# 9955            Supernatural  2005       TV-14      44.0
# 9956           Devil in Ohio  2022       TV-MA     356.0
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# 3           Drama, Horror, Mystery     5.9
# 4     Animation, Action, Adventure     8.6
# ...

# %%
data.mode()
# Out:
#       title  year certificate  duration   genre  rating description stars  \
# 0  Top Gear  2019       TV-MA  73.77162  Comedy     7.2  Add a Plot    []
#
#   votes main_genre  middle   right
# 0    30     Comedy   Drama   Drama

# %%
data.isnull().sum()
# Out:
# title             0
# year            527
# certificate    3453
# duration          0
# genre            73
# rating         1173
# description       0
# stars             0
# votes          1173
# main_genre       73
# middle         2690
# right          5072
# dtype: int64

# %%
data['certificate'] = data['certificate'].fillna(data['certificate'].mode()[0])
data
# Out:
#                        title  year certificate  duration  \
# 0                  Cobra Kai  2018       TV-14      30.0
# 1                  The Crown  2016       TV-MA      58.0
# 2           Better Call Saul  2015       TV-MA      46.0
# 3              Devil in Ohio  2022       TV-MA     356.0
# 4     Cyberpunk: Edgerunners  2022       TV-MA      24.0
# ...                      ...   ...         ...       ...
# 9952          The Imperfects  2022       TV-MA      45.0
# 9953        The Walking Dead  2010       TV-MA      44.0
# 9954               The Crown  2016       TV-MA      58.0
# 9955            Supernatural  2005       TV-14      44.0
# 9956           Devil in Ohio  2022       TV-MA     356.0
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# 3           Drama, Horror, Mystery     5.9
# 4     Animation, Action, Adventure     8.6
# ...

# %%
data['year'] = data['year'].fillna(data['year'].mode()[0])
data
# Out:
#                        title  year certificate  duration  \
# 0                  Cobra Kai  2018       TV-14      30.0
# 1                  The Crown  2016       TV-MA      58.0
# 2           Better Call Saul  2015       TV-MA      46.0
# 3              Devil in Ohio  2022       TV-MA     356.0
# 4     Cyberpunk: Edgerunners  2022       TV-MA      24.0
# ...                      ...   ...         ...       ...
# 9952          The Imperfects  2022       TV-MA      45.0
# 9953        The Walking Dead  2010       TV-MA      44.0
# 9954               The Crown  2016       TV-MA      58.0
# 9955            Supernatural  2005       TV-14      44.0
# 9956           Devil in Ohio  2022       TV-MA     356.0
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# 3           Drama, Horror, Mystery     5.9
# 4     Animation, Action, Adventure     8.6
# ...

# %%
genre = data['genre'].mode()[0]
data['genre'] = data['genre'].fillna(genre)
data
# Out:
#                        title  year certificate  duration  \
# 0                  Cobra Kai  2018       TV-14      30.0
# 1                  The Crown  2016       TV-MA      58.0
# 2           Better Call Saul  2015       TV-MA      46.0
# 3              Devil in Ohio  2022       TV-MA     356.0
# 4     Cyberpunk: Edgerunners  2022       TV-MA      24.0
# ...                      ...   ...         ...       ...
# 9952          The Imperfects  2022       TV-MA      45.0
# 9953        The Walking Dead  2010       TV-MA      44.0
# 9954               The Crown  2016       TV-MA      58.0
# 9955            Supernatural  2005       TV-14      44.0
# 9956           Devil in Ohio  2022       TV-MA     356.0
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# 3           Drama, Horror, Mystery     5.9
# 4     Animation, Action, Adventure     8.6
# ...

# %%
rating = data['rating'].mode()[0]
data['rating'] = data['rating'].fillna(rating)
data
# Out:
#                        title  year certificate  duration  \
# 0                  Cobra Kai  2018       TV-14      30.0
# 1                  The Crown  2016       TV-MA      58.0
# 2           Better Call Saul  2015       TV-MA      46.0
# 3              Devil in Ohio  2022       TV-MA     356.0
# 4     Cyberpunk: Edgerunners  2022       TV-MA      24.0
# ...                      ...   ...         ...       ...
# 9952          The Imperfects  2022       TV-MA      45.0
# 9953        The Walking Dead  2010       TV-MA      44.0
# 9954               The Crown  2016       TV-MA      58.0
# 9955            Supernatural  2005       TV-14      44.0
# 9956           Devil in Ohio  2022       TV-MA     356.0
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# 3           Drama, Horror, Mystery     5.9
# 4     Animation, Action, Adventure     8.6
# ...

# %%
data.isnull().sum()
# Out:
# title             0
# year              0
# certificate       0
# duration          0
# genre             0
# rating            0
# description       0
# stars             0
# votes          1173
# main_genre       73
# middle         2690
# right          5072
# dtype: int64

# %%
votes = data['votes'].mode()[0]
data['votes'] = data['votes'].fillna(votes)
data
# Out:
#                        title  year certificate  duration  \
# 0                  Cobra Kai  2018       TV-14      30.0
# 1                  The Crown  2016       TV-MA      58.0
# 2           Better Call Saul  2015       TV-MA      46.0
# 3              Devil in Ohio  2022       TV-MA     356.0
# 4     Cyberpunk: Edgerunners  2022       TV-MA      24.0
# ...                      ...   ...         ...       ...
# 9952          The Imperfects  2022       TV-MA      45.0
# 9953        The Walking Dead  2010       TV-MA      44.0
# 9954               The Crown  2016       TV-MA      58.0
# 9955            Supernatural  2005       TV-14      44.0
# 9956           Devil in Ohio  2022       TV-MA     356.0
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# 3           Drama, Horror, Mystery     5.9
# 4     Animation, Action, Adventure     8.6
# ...

# %%
data['year'].unique
# Out:
# <bound method Series.unique of 0       2018
# 1       2016
# 2       2015
# 3       2022
# 4       2022
#         ...
# 9952    2022
# 9953    2010
# 9954    2016
# 9955    2005
# 9956    2022
# Name: year, Length: 9957, dtype: object>

# %%
main_genre = data['main_genre'].mode()[0]
data['main_genre'] = data['main_genre'].fillna(main_genre)
data
# Out:
#                        title  year certificate  duration  \
# 0                  Cobra Kai  2018       TV-14      30.0
# 1                  The Crown  2016       TV-MA      58.0
# 2           Better Call Saul  2015       TV-MA      46.0
# 3              Devil in Ohio  2022       TV-MA     356.0
# 4     Cyberpunk: Edgerunners  2022       TV-MA      24.0
# ...                      ...   ...         ...       ...
# 9952          The Imperfects  2022       TV-MA      45.0
# 9953        The Walking Dead  2010       TV-MA      44.0
# 9954               The Crown  2016       TV-MA      58.0
# 9955            Supernatural  2005       TV-14      44.0
# 9956           Devil in Ohio  2022       TV-MA     356.0
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# 3           Drama, Horror, Mystery     5.9
# 4     Animation, Action, Adventure     8.6
# ...

# %%
data.isnull().sum()
# Out:
# title             0
# year              0
# certificate       0
# duration          0
# genre             0
# rating            0
# description       0
# stars             0
# votes             0
# main_genre        0
# middle         2690
# right          5072
# dtype: int64

# %%
rslt_df = data[data['rating'] >= 9.9]
rslt_df
# Out:
#                 title  year certificate  duration                     genre  \
# 9444  BoJack Horseman  2014       TV-MA      26.0  Animation, Comedy, Drama
#
#       rating                                  description  \
# 9444     9.9  BoJack reconnects with faces from his past.
#
#                                                   stars   votes main_genre  \
# 9444  ['Amy Winfrey', '| ', '    Stars:', 'Will Arne...  16,066  Animation
#
#        middle   right
# 9444   Comedy   Drama

# %%
n_by_state = data.groupby("certificate")["title"].count()
n_by_state
# Out:
# certificate
# 12              1
# Approved       26
# E10+            1
# G              43
# M               1
# MA-17           1
# NC-17           4
# Not Rated     467
# PG            159
# PG-13         282
# Passed          6
# R             472
# TV-14        1209
# TV-G          151
# TV-MA        5973
# TV-PG         543
# TV-Y          175
# TV-Y7         349
# TV-Y7-FV       31
# Unrated        63
# Name: title, dtype: int64

# %%
data
# Out:
#                        title  year certificate  duration  \
# 0                  Cobra Kai  2018       TV-14      30.0
# 1                  The Crown  2016       TV-MA      58.0
# 2           Better Call Saul  2015       TV-MA      46.0
# 3              Devil in Ohio  2022       TV-MA     356.0
# 4     Cyberpunk: Edgerunners  2022       TV-MA      24.0
# ...                      ...   ...         ...       ...
# 9952          The Imperfects  2022       TV-MA      45.0
# 9953        The Walking Dead  2010       TV-MA      44.0
# 9954               The Crown  2016       TV-MA      58.0
# 9955            Supernatural  2005       TV-14      44.0
# 9956           Devil in Ohio  2022       TV-MA     356.0
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# 3           Drama, Horror, Mystery     5.9
# 4     Animation, Action, Adventure     8.6
# ...
